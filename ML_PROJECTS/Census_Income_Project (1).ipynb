# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('/content/adult[1].csv')

# %%
df1
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df1.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 52

# %%
df1.shape
# Out:
# (48842, 15)

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (48790, 15)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48790 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48790 non-null  int64
#  1   workclass        48790 non-null  object
#  2   fnlwgt           48790 non-null  int64
#  3   education        48790 non-null  object
#  4   educational-num  48790 non-null  int64
#  5   marital-status   48790 non-null  object
#  6   occupation       48790 non-null  object
#  7   relationship     48790 non-null  object
#  8   race             48790 non-null  object
#  9   gender           48790 non-null  object
#  10  capital-gain     48790 non-null  int64
#  11  capital-loss     48790 non-null  int64
#  12  hours-per-week   48790 non-null  int64
#  13  native-country   48790 non-null  object
#  14  income           48790 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 6.0+ MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48790 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48790 non-null  int64
#  1   workclass        48790 non-null  object
#  2   fnlwgt           48790 non-null  int64
#  3   education        48790 non-null  object
#  4   educational-num  48790 non-null  int64
#  5   marital-status   48790 non-null  object
#  6   occupation       48790 non-null  object
#  7   relationship     48790 non-null  object
#  8   race             48790 non-null  object
#  9   gender           48790 non-null  object
#  10  capital-gain     48790 non-null  int64
#  11  capital-loss     48790 non-null  int64
#  12  hours-per-week   48790 non-null  int64
#  13  native-country   48790 non-null  object
#  14  income           0 non-null      float64
# dtypes: float64(1), int64(6), object(8)
# memory usage: 6.0+ MB

# %%
for i in df1.columns:
  if df1[i].dtypes=='object':
    print(df1[i].value_counts())
    print('------------------')
# Out:
# Private             33860
# Self-emp-not-inc     3861
# Local-gov            3136
# ?                    2795
# State-gov            1981
# Self-emp-inc         1694
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64
# ------------------
# HS-grad         15770
# Some-college    10863
# Bachelors        8013
# Masters          2656
# Assoc-voc        2060
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           954
# Prof-school       834
# 9th               756
# 12th              655
# Doctorate         594
# 5th-6th           507
# 1st-4th           245
# Preschool          81
# Name: education, dtype: int64
# ------------------
# Married-civ-spouse       22366
# Never-married            16082
# Divorced                  6630
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      627
# Married-AF-spouse           37
# ...

# %%
df1.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df1.describe().T
# Out:
#                    count           mean            std      min       25%  \
# age              48790.0      38.652798      13.708493     17.0      28.0
# fnlwgt           48790.0  189668.999365  105617.231232  12285.0  117555.0
# educational-num  48790.0      10.078807       2.570046      1.0       9.0
# capital-gain     48790.0    1080.217688    7455.905921      0.0       0.0
# capital-loss     48790.0      87.595573     403.209129      0.0       0.0
# hours-per-week   48790.0      40.425886      12.392729      1.0      40.0
# income               0.0            NaN            NaN      NaN       NaN
#
#                       50%        75%        max
# age                  37.0      48.00       90.0
# fnlwgt           178138.5  237606.25  1490400.0
# educational-num      10.0      12.00       16.0
# capital-gain          0.0       0.00    99999.0
# capital-loss          0.0       0.00     4356.0
# hours-per-week       40.0      45.00       99.0
# ...

# %%
df1.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
# ...

# %%
df1.replace('?',pd.NA,inplace=True)

# %%
df1.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18       <NA>  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4               <NA>    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df1.dropna(inplace=True)

# %%
df1.shape
# Out:
# (45175, 15)

# %%
df1.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 5   34    Private  198693          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
# ...

# %%
sns.boxplot(x='educational-num',data=df1)
# Out:
# <Axes: xlabel='educational-num'>

# %%
for i in df1.columns:
  if (df1[i].dtypes==int or df1[i].dtypes==float):
       print(df1[i])
# Out:
# 0        25
# 1        38
# 2        28
# 3        44
# 5        34
#          ..
# 48837    27
# 48838    40
# 48839    58
# 48840    22
# 48841    52
# Name: age, Length: 45175, dtype: int64
# 0        226802
# 1         89814
# 2        336951
# 3        160323
# 5        198693
#           ...
# 48837    257302
# 48838    154374
# 48839    151910
# 48840    201490
# 48841    287927
# Name: fnlwgt, Length: 45175, dtype: int64
# 0         7
# 1         9
# 2        12
# 3        10
# 5         6
#          ..
# 48837    12
# 48838     9
# 48839     9
# 48840     9
# 48841     9
# Name: educational-num, Length: 45175, dtype: int64
# 0            0
# 1            0
# 2            0
# 3         7688
# 5            0
#          ...
# 48837        0
# 48838        0
# 48839        0
# 48840        0
# 48841    15024
# Name: capital-gain, Length: 45175, dtype: int64
# 0        0
# 1        0
# 2        0
# 3        0
# 5        0
#         ..
# 48837    0
# 48838    0
# 48839    0
# ...

# %%
for i in df1.columns:
    if (df1[i].dtypes=='int' or df1[i].dtypes=='float'):
      sns.boxplot(df1[i])
      plt.xlabel(i)
      plt.ylabel('count')
      plt.show()

# %%
df1.describe().T
# Out:
#                    count           mean            std      min       25%  \
# age              45175.0      38.556170      13.215349     17.0      28.0
# fnlwgt           45175.0  189738.798450  105652.436515  13492.0  117392.5
# educational-num  45175.0      10.119314       2.551740      1.0       9.0
# capital-gain     45175.0    1102.576270    7510.249876      0.0       0.0
# capital-loss     45175.0      88.687593     405.156611      0.0       0.0
# hours-per-week   45175.0      40.942512      12.007730      1.0      40.0
#
#                       50%       75%        max
# age                  37.0      47.0       90.0
# fnlwgt           178312.0  237903.0  1490400.0
# educational-num      10.0      13.0       16.0
# capital-gain          0.0       0.0    99999.0
# capital-loss          0.0       0.0     4356.0
# hours-per-week       40.0      45.0       99.0

# %%
col=['fnlwgt','hours-per-week']
for i in col:
  q1=df1[i].quantile(0.25)
  q3=df1[i].quantile(0.75)
  iqr=q3-q1
  df1=df1[(df1[i]>=q1-1.5*iqr)&(df1[i]<=q3+1.5*iqr)]

# %%
df1.shape
# Out:
# (32267, 15)

# %%
df1.describe().T
# Out:
#                    count           mean           std      min       25%  \
# age              32267.0      39.008833     12.171913     17.0      29.0
# fnlwgt           32267.0  181048.361887  87186.436414  13769.0  117066.0
# educational-num  32267.0      10.155763      2.505886      1.0       9.0
# capital-gain     32267.0     998.620448   6726.764854      0.0       0.0
# capital-loss     32267.0      90.518765    407.593737      0.0       0.0
# hours-per-week   32267.0      41.616946      4.048884     33.0      40.0
#
#                       50%       75%       max
# age                  38.0      47.0      90.0
# fnlwgt           176814.0  230684.0  418645.0
# educational-num      10.0      13.0      16.0
# capital-gain          0.0       0.0   99999.0
# capital-loss          0.0       0.0    3900.0
# hours-per-week       40.0      43.0      52.0

# %% [markdown]
# Insights for Each Column:
# Age:
#
# Average age is approximately 39 years, with a minimum of 17 and a maximum of 90.
# The majority of individuals fall between 29 and 47 years, as indicated by the interquartile range (25th to 75th percentile).
#
# Final Weight (fnlwgt):
#
# The average final weight is around 181,048.
# The data spans from 13,769 to 418,645, with a significant standard deviation, indicating possible variability or spread.
#
# Educational Number (educational-num):
#
# The average educational number is approximately 10, indicating a level around high school or some college.
# Most individuals have an educational number between 9 and 13, according to the interquartile range.
#
# Capital Gain and Loss (capital-gain & capital-loss):
#
# Both capital-gain and capital-loss tend to be concentrated around zero.
# There are individuals with high capital gains (up to 99,999) and losses (up to 3,900), but these are not common, as indicated by the higher percentiles being zero.
#
# Hours per Week (hours-per-week):
#
# On average, individuals work around 41 hours per week.
# The range is from 33 to 52 hours, with most falling between 40 and 43 hours based on the interquartile range.

# %%
df1.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 8   24    Private  369667  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 8      Other-service    Unmarried  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
sns.countplot(x='income',data=df1,hue='workclass')
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
sns.countplot(x='marital-status',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='income',data=df1,hue='marital-status')
plt.legend(loc='best')

# %%
plt.hist(df1['age'])
# Out:
# (array([3788., 6363., 6662., 6723., 4398., 2745., 1253.,  231.,   60.,
#           44.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x='education',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='income',data=df1,hue='gender')
# Out:
# <Axes: xlabel='income', ylabel='count'>

# %%
df1.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
sns.countplot(x='native-country',data=df1,hue='income')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='occupation',data=df1)
plt.xticks(rotation=90)
plt.show()

# %%
df1.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 8   24    Private  369667  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 8      Other-service    Unmarried  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df1['income']=df1['income'].map({'<=50K':0,'>50K':1})

# %%
df1['income'].value_counts()
# Out:
# 0    23851
# 1     8416
# Name: income, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le
# Out:
# LabelEncoder()

# %%
for i in df1.columns:
  if df1[i].dtypes=='object':
    df1[i]=le.fit_transform(df1[i])

# %%
df1.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   25          2  226802          1                7               4
# 1   38          2   89814         11                9               2
# 2   28          1  336951          7               12               2
# 3   44          2  160323         15               10               2
# 8   24          2  369667         15               10               4
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           6             3     2       1             0             0
# 1           4             0     4       1             0             0
# 2          10             0     4       1             0             0
# 3           6             0     2       1          7688             0
# 8           7             4     4       0             0             0
#
#    hours-per-week  native-country  income
# 0              40              38       0
# ...

# %%
df1['capital-gain'].value_counts()
# Out:
# 0        29506
# 15024      340
# 7688       301
# 7298       282
# 99999      128
#          ...
# 22040        1
# 1424         1
# 2036         1
# 5060         1
# 2936         1
# Name: capital-gain, Length: 109, dtype: int64

# %%
x=df1.iloc[:,:-1]
y=df1.iloc[:,-1]

# %%
x
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0       25          2  226802          1                7               4
# 1       38          2   89814         11                9               2
# 2       28          1  336951          7               12               2
# 3       44          2  160323         15               10               2
# 8       24          2  369667         15               10               4
# ...    ...        ...     ...        ...              ...             ...
# 48836   22          2  310152         15               10               4
# 48837   27          2  257302          7               12               2
# 48838   40          2  154374         11                9               2
# 48839   58          2  151910         11                9               6
# 48841   52          3  287927         11                9               2
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 8        0
#         ..
# 48836    0
# 48837    0
# 48838    1
# 48839    0
# 48841    1
# Name: income, Length: 32267, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
ss
# Out:
# StandardScaler()

# %%
scaled_data=ss.fit_transform(x)
scaled_data
# Out:
# array([[-1.15093242, -0.157843  ,  0.52478744, ..., -0.2220843 ,
#         -0.39936218,  0.26399449],
#        [-0.08288329, -0.157843  , -1.0464446 , ..., -0.2220843 ,
#          2.07049242,  0.26399449],
#        [-0.90445955, -1.21538453,  1.78818014, ..., -0.2220843 ,
#         -0.39936218,  0.26399449],
#        ...,
#        [ 0.08143196, -0.157843  , -0.30595098, ..., -0.2220843 ,
#         -0.39936218,  0.26399449],
#        [ 1.56026923, -0.157843  , -0.33421269, ..., -0.2220843 ,
#         -0.39936218,  0.26399449],
#        [ 1.06732347,  0.89969853,  1.22588213, ..., -0.2220843 ,
#         -0.39936218,  0.26399449]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=7)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 25813
# 6454
# 25813
# 6454

# %%
from sklearn.linear_model import LogisticRegression
logmodel=LogisticRegression()
logmodel
# Out:
# LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logmodel.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_train,logmodel.predict(x_train))
# Out:
# 0.7807306396002015

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7716145026340254

# %% [markdown]
# Build Decision_tree model

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(criterion='gini',max_depth=5,random_state=42)
dtc
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred=dtc.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_train,logmodel.predict(x_train))
# Out:
# 0.7807306396002015

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100,criterion='gini',max_depth=10,min_samples_leaf=1,max_features='sqrt',oob_score=False,random_state=7,min_samples_split=2)
rfc
# Out:
# RandomForestClassifier(max_depth=10, random_state=7)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=7)

# %%
y_pred=rfc.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 0.8306476603656647

# %%
accuracy_score(y_train,rfc.predict(x_train))
# Out:
# 0.8617750745748266
